# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesqiu2021/DSCI-401-QW/blob/main/Data_Wrangling_Single_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cia = pd.read_csv("https://raw.githubusercontent.com/gjm112/DSCI401/main/data/CIACountries.csv")
print(cia.columns)
cia.head
# Out:
# Index(['country', 'pop', 'area', 'oil_prod', 'gdp', 'educ', 'roadways',
#        'net_users'],
#       dtype='object')
# <bound method NDFrame.head of             country       pop       area   oil_prod      gdp  educ  roadways  \
# 0       Afghanistan  32564342   652230.0        0.0   1900.0   NaN  0.064624
# 1           Albania   3029278    28748.0    20510.0  11900.0   3.3  0.626131
# 2           Algeria  39542166  2381741.0  1420000.0  14500.0   4.3  0.047719
# 3    American Samoa     54343      199.0        0.0  13000.0   NaN  1.211055
# 4           Andorra     85580      468.0        NaN  37200.0   NaN  0.683761
# ..              ...       ...        ...        ...      ...   ...       ...
# 231       West Bank   2785366     5860.0        0.0   4300.0   NaN  0.799659
# 232  Western Sahara    570866   266000.0        0.0   2500.0   NaN       NaN
# 233           Yemen  26737317   527968.0   125100.0   2700.0   5.2  0.135046
# ...

# %%
cia.describe()
# Out:
#          population          area      oil_prod            gdp        educ  \
# count  2.360000e+02  2.360000e+02  2.130000e+02     228.000000  173.000000
# mean   3.074785e+07  5.778759e+05  3.731250e+05   21398.245614    4.854913
# std    1.256159e+08  1.763384e+06  1.324249e+06   22462.473777    2.142928
# min    4.800000e+01  0.000000e+00  0.000000e+00     400.000000    0.600000
# 25%    3.435062e+05  2.498250e+03  0.000000e+00    4775.000000    3.300000
# 50%    5.311480e+06  7.358000e+04  0.000000e+00   13750.000000    4.700000
# 75%    1.835076e+07  4.146432e+05  5.113000e+04   31650.000000    5.900000
# max    1.367485e+09  1.709824e+07  1.084000e+07  132100.000000   13.000000
#
#          roadways
# count  223.000000
# mean     1.108489
# std      3.048419
# min      0.006393
# 25%      0.122394
# 50%      0.334738
# 75%      1.153948
# max     38.500000

# %% [markdown]
# # Rename

# %%
#I'm going to change the name of pop because that's a function in python.
cia = cia.rename(columns={"pop": "population"})
cia.head
# Out:
# <bound method NDFrame.head of             country  population       area   oil_prod      gdp  educ  \
# 0       Afghanistan    32564342   652230.0        0.0   1900.0   NaN
# 1           Albania     3029278    28748.0    20510.0  11900.0   3.3
# 2           Algeria    39542166  2381741.0  1420000.0  14500.0   4.3
# 3    American Samoa       54343      199.0        0.0  13000.0   NaN
# 4           Andorra       85580      468.0        NaN  37200.0   NaN
# ..              ...         ...        ...        ...      ...   ...
# 231       West Bank     2785366     5860.0        0.0   4300.0   NaN
# 232  Western Sahara      570866   266000.0        0.0   2500.0   NaN
# 233           Yemen    26737317   527968.0   125100.0   2700.0   5.2
# 234          Zambia    15066266   752618.0        0.0   3900.0   1.3
# 235        Zimbabwe    14229541   390757.0        0.0   2100.0   2.5
#
#      roadways net_users
# 0    0.064624       >5%
# 1    0.626131      >35%
# 2    0.047719      >15%
# ...

# %%
print(cia.shape)
print(type(cia.country))
# Out:
# (236, 8)
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Filter and select

# %%
cia[0:3]
# Out:
#        country  population       area   oil_prod      gdp  educ  roadways  \
# 0  Afghanistan    32564342   652230.0        0.0   1900.0   NaN  0.064624
# 1      Albania     3029278    28748.0    20510.0  11900.0   3.3  0.626131
# 2      Algeria    39542166  2381741.0  1420000.0  14500.0   4.3  0.047719
#
#   net_users
# 0       >5%
# 1      >35%
# 2      >15%

# %%
cia["population"]
# Out:
# 0      32564342
# 1       3029278
# 2      39542166
# 3         54343
# 4         85580
#          ...
# 231     2785366
# 232      570866
# 233    26737317
# 234    15066266
# 235    14229541
# Name: population, Length: 236, dtype: int64

# %%
cia.loc[0:3,["population","area"]]
# Out:
#    population       area
# 0    32564342   652230.0
# 1     3029278    28748.0
# 2    39542166  2381741.0
# 3       54343      199.0

# %%
#Subet of rows based on a condition
cia[cia["population"] > 1000000000]

#Or this
cia[cia.population > 1000000000]

#Note that this doesn't work if I leave the name as pop!
#cia[cia.pop > 1000000000]
# Out:
#    country  population       area   oil_prod      gdp  educ  roadways  \
# 42   China  1367485388  9596960.0  4189000.0  14100.0   NaN  0.427884
# 96   India  1251695584  3287263.0   767600.0   6200.0   3.2  1.426671
#
#    net_users
# 42      >35%
# 96      >15%

# %%
cia[cia["pop"] > 1000000000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pop'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Subset of columns
cia[["country","population","gdp"]]
# Out:
#             country  population      gdp
# 0       Afghanistan    32564342   1900.0
# 1           Albania     3029278  11900.0
# 2           Algeria    39542166  14500.0
# 3    American Samoa       54343  13000.0
# 4           Andorra       85580  37200.0
# ..              ...         ...      ...
# 231       West Bank     2785366   4300.0
# 232  Western Sahara      570866   2500.0
# 233           Yemen    26737317   2700.0
# 234          Zambia    15066266   3900.0
# 235        Zimbabwe    14229541   2100.0
#
# [236 rows x 3 columns]

# %% [markdown]
# # Filter and select together

# %%
#Subset of columns 
cia[cia.population > 1000000000][["country","population","gdp"]]
# Out:
#    country  population      gdp
# 42   China  1367485388  14100.0
# 96   India  1251695584   6200.0

# %%
#Or you can use loc
cia.loc[cia.population > 1000000000,["country","population","gdp"]]
# Out:
#    country  population      gdp
# 42   China  1367485388  14100.0
# 96   India  1251695584   6200.0

# %% [markdown]
# # Mutate and rename

# %%
cia["dens"] = cia["population"]/cia["area"]
cia.head()
# Out:
#           country  population       area   oil_prod      gdp  educ  roadways  \
# 0     Afghanistan    32564342   652230.0        0.0   1900.0   NaN  0.064624
# 1         Albania     3029278    28748.0    20510.0  11900.0   3.3  0.626131
# 2         Algeria    39542166  2381741.0  1420000.0  14500.0   4.3  0.047719
# 3  American Samoa       54343      199.0        0.0  13000.0   NaN  1.211055
# 4         Andorra       85580      468.0        NaN  37200.0   NaN  0.683761
#
#   net_users        dens
# 0       >5%   49.927697
# 1      >35%  105.373522
# 2      >15%   16.602211
# 3       NaN  273.080402
# 4      >60%  182.863248

# %%
#I already did this, but here it is again.
cia = cia.rename(columns={"pop": "population"})
cia.head
# Out:
# <bound method NDFrame.head of             country  population       area   oil_prod      gdp  educ  \
# 0       Afghanistan    32564342   652230.0        0.0   1900.0   NaN
# 1           Albania     3029278    28748.0    20510.0  11900.0   3.3
# 2           Algeria    39542166  2381741.0  1420000.0  14500.0   4.3
# 3    American Samoa       54343      199.0        0.0  13000.0   NaN
# 4           Andorra       85580      468.0        NaN  37200.0   NaN
# ..              ...         ...        ...        ...      ...   ...
# 231       West Bank     2785366     5860.0        0.0   4300.0   NaN
# 232  Western Sahara      570866   266000.0        0.0   2500.0   NaN
# 233           Yemen    26737317   527968.0   125100.0   2700.0   5.2
# 234          Zambia    15066266   752618.0        0.0   3900.0   1.3
# 235        Zimbabwe    14229541   390757.0        0.0   2100.0   2.5
#
#      roadways net_users        dens
# 0    0.064624       >5%   49.927697
# ...

# %%
cia = cia.rename(columns={"pop": "population"})
cia.head
# Out:
# <bound method NDFrame.head of             country  population       area   oil_prod      gdp  educ  \
# 0       Afghanistan    32564342   652230.0        0.0   1900.0   NaN
# 1           Albania     3029278    28748.0    20510.0  11900.0   3.3
# 2           Algeria    39542166  2381741.0  1420000.0  14500.0   4.3
# 3    American Samoa       54343      199.0        0.0  13000.0   NaN
# 4           Andorra       85580      468.0        NaN  37200.0   NaN
# ..              ...         ...        ...        ...      ...   ...
# 231       West Bank     2785366     5860.0        0.0   4300.0   NaN
# 232  Western Sahara      570866   266000.0        0.0   2500.0   NaN
# 233           Yemen    26737317   527968.0   125100.0   2700.0   5.2
# 234          Zambia    15066266   752618.0        0.0   3900.0   1.3
# 235        Zimbabwe    14229541   390757.0        0.0   2100.0   2.5
#
#      roadways net_users
# 0    0.064624       >5%
# 1    0.626131      >35%
# 2    0.047719      >15%
# ...

# %% [markdown]
# # Sorting

# %%
cia.sort_values(by = "population", ascending = False)
# Out:
#                      country  population       area   oil_prod      gdp  educ  \
# 42                     China  1367485388  9596960.0  4189000.0  14100.0   NaN
# 96                     India  1251695584  3287263.0   767600.0   6200.0   3.2
# 223            United States   321368864  9826675.0  8653000.0  55800.0   5.4
# 97                 Indonesia   255993674  1904569.0   789800.0  11100.0   2.8
# 27                    Brazil   204259812  8514877.0  2255000.0  15600.0   5.8
# ..                       ...         ...        ...        ...      ...   ...
# 211                  Tokelau        1337       12.0        NaN   1000.0   NaN
# 154                     Niue        1190      260.0        0.0   5800.0   NaN
# 91   Holy See (Vatican City)         842        0.0        NaN      NaN   NaN
# 44   Cocos (Keeling) Islands         596       14.0        NaN      NaN   NaN
# 166         Pitcairn Islands          48       47.0        NaN      NaN   NaN
#
#      roadways net_users
# ...

# %%
cia.sort_values(by = "population", ascending = True)
# Out:
#                      country  population       area   oil_prod      gdp  educ  \
# 166         Pitcairn Islands          48       47.0        NaN      NaN   NaN
# 44   Cocos (Keeling) Islands         596       14.0        NaN      NaN   NaN
# 91   Holy See (Vatican City)         842        0.0        NaN      NaN   NaN
# 154                     Niue        1190      260.0        0.0   5800.0   NaN
# 211                  Tokelau        1337       12.0        NaN   1000.0   NaN
# ..                       ...         ...        ...        ...      ...   ...
# 27                    Brazil   204259812  8514877.0  2255000.0  15600.0   5.8
# 97                 Indonesia   255993674  1904569.0   789800.0  11100.0   2.8
# 223            United States   321368864  9826675.0  8653000.0  55800.0   5.4
# 96                     India  1251695584  3287263.0   767600.0   6200.0   3.2
# 42                     China  1367485388  9596960.0  4189000.0  14100.0   NaN
#
# ...

# %% [markdown]
# # Summarize and grouping

# %%
cia["high_educ"] = cia["educ"] > 4.5
cia[["high_educ","area"]].dropna(how = "any").groupby("high_educ").mean()
# Out:
#                     area
# high_educ
# False      490582.442177
# True       722057.325843

# %%
cia.loc[cia["educ"].notna()].groupby("high_educ").mean()
# Out:
#              population           area       oil_prod           gdp      educ  \
# high_educ
# False      3.929746e+07  602414.535714  375269.162500  22771.084337  3.208333
# True       2.390677e+07  722057.325843  403539.333333  19567.415730  6.408989
#
#            roadways        dens
# high_educ
# False      1.458381  774.764043
# True       0.929741  148.743308

# %%
cia.loc[cia["educ"].notna()].groupby("high_educ").mean()["area"]
# Out:
# high_educ
# False    602414.535714
# True     722057.325843
# Name: area, dtype: float64

# %% [markdown]
# #In class assignments!
#
# *   What first letter has the largest population?
# *   What proportion of countries produce any oil stratified by net users class?

# %%
cia = cia[cia["oil_prod"].notna()]
cia["oil_produce"]=cia["oil_prod"]>0
binaries = []
for i in cia ["oil_produce"]:
  binaries.append(int(i))
cia['oil']=binaries
cia.head()
cia [["oil","net_users"]].dropna(how="any").groupby("net_users").mean()
# Out:
#                 oil
# net_users
# >0%        0.347826
# >15%       0.545455
# >35%       0.596491
# >5%        0.241379
# >60%       0.492063

# %%
cia["first_letter"]=cia["country"].str[0]
cia.groupby ('first_letter').sum().sort_values (by="population",ascending = False)
# Out:
#               population        area    oil_prod       gdp   educ   roadways
# first_letter
# I             1701785899   7774299.0   8645490.0  304200.0   33.8   6.822307
# C             1664413032  27363455.0   9628866.0  308400.0   87.5  16.076813
# B              518195981  11913020.0   2539948.0  459300.0   85.5  27.080947
# U              505309897  11622088.0  12365500.0  201700.0   25.6   3.336763
# P              400649115   3745394.0    241770.0  165100.0   34.0   5.614976
# S              289078777   8454263.0  10278194.0  695700.0  109.2  31.376706
# M              285441887   8157730.0   3083853.0  371500.0   85.6  78.374569
# N              266210163   3945022.0   4078980.0  252600.0   42.1  10.099450
# T              256487071   3153292.0    736635.0  195000.0   46.0   6.099345
# E              218496813   2601231.0   1282800.0   94900.0   24.7   2.088462
# A              182807690  15032634.0   4936570.0  308700.0   45.8   9.783171
# ...
